# %% [markdown]
# # Milestone 1 Assignment - Capstone Proposal
#
# ## Author - Elizabeth Lunsford

# %% [markdown]
# ### Capstone Project Instructions
# Select a problem and data sets of particular interest and apply the analytics process to find and report on a solution.
#
# Students will construct a simple dashboard to allow a non-technical user to explore their solution. The data should be read from a suitable persistent data storage, such as an Internet URL or a SQL data base.
#
# The process followed by the students and the grading criteria include:
# <ol style="list-style-type: lower-alpha;">
# <li>Understand the business problem <span class="label" style="border-radius: 3px; background-color: darkcyan; color: white;">Milestone 1</span></li>
# <li>Evaluate and explore the available data <span class="label" style="border-radius: 3px; background-color: darkcyan; color: white;">Milestone 1</span></li>
# <li>Proper data preparation <span class="label" style="border-radius: 3px; background-color: darkcyan; color: white;">Milestone 1</span> <span class="label" style="border-radius: 3px; background-color: royalblue; color: white;">Milestone 2</span></li>
# <li>Exploration of data and understand relationships <span class="label" style="border-radius: 3px; background-color: darkcyan; color: white;">Milestone 1</span> <span class="label" style="border-radius: 3px; background-color: royalblue; color: white;">Milestone 2</span></li>
# <li>Perform basic analytics and machine learning, within the scope of the course, on the data.  <span class="label" style="border-radius: 3px; background-color: royalblue; color: white;">Milestone 2</span> <span class="label" style="border-radius: 3px; background-color: slateblue; color: white;">Milestone 3</span> <BR/>For example, classification to predict which employees are most likely to leave the company.</li>
# <li>Create a written and/or oral report on the results suitable for a non-technical audience. <span class="label" style="border-radius: 3px; background-color: slateblue; color: white;">Milestone 3</span></li>
# </ol>

# %% [markdown]
# ## Tasks
# For this proposal, you are to:
# 1. Generate or describe a solvable business problem and outline the flow of data needed to address the problem.
# 2. Identify 2 or more available data sets
# 3. Report on the statistics of each data set to include: type, unique values, missing values, quantile statistics, descriptive statistics, most frequent values, and histogram. Include analysis statements based on results.
# 4. Perform data preparation based on analysis of the quality of the available data include concatenation method, imputation method(s), dealing with outliers, and binning/scaling transformation.
# 5. Output the resulting data into a new data file
# 6. Identify potential machine learning model(s)

# %% [markdown]
# ## Problem Definition

# %% [markdown]
# Understanding how the United States of America is governed is a complex problem.   Simply described as a democracy where people vote for elected officials is an overgeneralization for the constitutional federal republic which is governed by three branches; executive, legislative and judicial.  The judicial branch ensures that implemented laws are in accordance with the constitution that can be either places by the executive or legislative branches.
#
# Each state has its own constitution and form of government that is also structured with executive, legislative and judicial branch.  A republic is a form of government in which the people elect representatives.  In the United States, people elect officials into the legislative branches based on popular vote.  The Federal Executive branch which included the President and Vice President of the United States is elected by an electoral college.  The electoral college mainly consists of two political parties; the Democratic and Republican Party
#
# The republic is not required to vote or align themselves to a political party. Therefore voter turnout is a dynamic variable and a state’s political majority can change at every election.
# To help understand how the United States is govern, we will study if social demographics have an influence on how people vote. Using Machine Learning Algorithms, we will create model to predict each state’s range of voter turnout and which party will be elected in federal elections.

# %% [markdown]
# ![title](Elizabeth_Lunsford-M01-DFD-Capstone.png)

# %% [markdown]
# ## Data Sets

# %% [markdown]
# # Datasets location
# ## United States Presidential Election Results Data Set
#
# URL = "https://uselectionatlas.org/RESULTS/"
#
# Data was collected for elections back to 1968 following the steps below.
# - Select "Popular Vote State-Level Data (Table)"
# - Include the following features
#   - Population
#   - Voting Age Population
#   - Voting Age Citizens
#   - Registered Voters
#   - Voter Turnout (Vote for President as a % Voting Age Population)
#   - Voter Turnout (Vote for President as a % Voting Age Citizens)
#   - Voter Turnout (Vote for President as a % Registered Voters)
# - Copy and Paste Results into a spreadsheet
# - Align Candidate with Party
# - Under the Menu, select the another year and repeat steps
# - Export data into csv file name "presidential_election_data.csv"

# %%
filename =  "presidential_election_data.csv"
import pandas as pd
df_pr = pd.read_csv(filename, header=0)

# %% [markdown]
# ## United States Legislative Branch Party Compositions
#
# URL = https://www.kaggle.com/kiwiphrases/partystrengthbystate#states_party_strength_cleaned.csv
#
# Data file is from Kaggle that was a collective data scrap of each state's Wikipedia table of elected state legislators.

# %%
filename2 = "states_party_strength_cleaned.csv"
df_lg = pd.read_csv(filename2, header=0)

# %% [markdown]
# ## Profile Reports & Analysis Statements
# Pandas library profiling has a method the generates a report that includes
# - type
# - unique values
# - missing values
# - quantile statistics
# - descriptive statistics
# - most frequent values
# - histogram.

# %%
# Import libraries
import pandas_profiling

# %% [markdown]
# ### Presidential Election Results Profile Reports & Analysis Statements

# %%
pandas_profiling.ProfileReport(df_pr)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>25 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>663 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>6.8% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>129.6 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>200.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_EV_D"><code>EV_D</code></a> has 419 / 63.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_EV_R"><code>EV_R</code></a> has 247 / 37.3% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_O_placed"><code>O_placed</code></a> has 357 / 53.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Perc_REG"><code>Perc_REG</code></a> has a high cardinality: 272 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Perc_VAP"><code>Perc_VAP</code></a> has a high cardinality: 269 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Population"><code>Population</code></a> has 51 / 7.7% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_State"><code>State</code></a> has a high cardinality: 51 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Total_REG"><code>Total_REG</code></a> is highly correlated with <a href="#pp_var_Population"><code>Population</code></a> (ρ = 0.96547) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Total_VAC"><code>Tot

# %% [markdown]
# ### Presidential Election Results Analysis statements based on results.
#
# - Analysis
#  - The Presidential Election Data has quality election data grouped by each state.  An analysis of a state's population, turn out of voters, percentage of vote per party and classifer of what party won in each state can be used from this dataset.  However, the data needs to be cleaned by imputation of missing data and removing redundant data.
# - Keys
#  * D is for Democrat
#  * R is for Republican
#  * T is for Third Party
#  * O is for Other
# - Numerical Values
#  - EV_R is how many electoral votes the Republican Candidate received
#  - EV_D is how many electoral votes the Democrat Candidate received
#  - Population is the population of the state
#  - Total_REG is the amount of registered voters in the state
#  - Total_VAP Voting Age Population
#  - Total_VAC Voting Age Citizens
#  - Perc_VAP Voter Turnout (Vote for President as a % Voting Age Population)
#  - Perc_VAC Voter Turnout (Vote for President as a % Voting Age Citizens)
#  - Perc_VAP Voter Turnout (Vote for President as a % Registered Voters)
#  - Total_Vote is the amount of votes there were in the state for the election
#  - Perc_reg is the percentage of the state's population that are registered voters
#  - D_placed, R_placed, O_placed is the what place the candidate came in the election, 1 is the winner
#  - Margin is the difference between first and second place
#  - Perc_Margin is the percentage difference in votes betweeen first and second place
#  - Vote_Perc_D, Vote_Perc_R, Vote_Perc_T, Vote_Perc_O is the percentage of votes the candidate recieved in the state
#  - Vote_D, Vote_R, Vote_T, Vote_O is the amount of votes the candidate recieved in the state
# - Categorical
#  - State - there are 51 states because the District of Columbia recieves it's own electorial votes
# - Variables that have too many missing values
#  - Total_VAC
#  - Perc_VAC
# - Variables that are redundant
#  - Margin : The Percentage Margin and the population who voted can calculate the same data.
#  - Vote_R, Vote_D, Vote_T, Vote_O: The Percentage of Votes per candidate and total votes can caluculate the same data

# %% [markdown]
# ### Legislative Party Composition Reports & Analysis Statements

# %%
pandas_profiling.ProfileReport(df_lg)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>11 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>2012 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>11.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>173.0 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>88.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_congress house"><code>congress house</code></a> has 34 / 1.7% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_congress house"><code>congress house</code></a> has a high cardinality: 183 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_congress sen"><code>congress sen</code></a> has 84 / 4.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_congress sen class 1"><code>congress sen class 1</code></a> has 702 / 34.9% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_congress sen class 2"><code>congress sen class 2</code></a> has 684 / 34.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_congress sen class 3"><code>congress sen class 3</code></a> has 648 / 32.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_electoral"><code>electoral</code></a> has 92 / 4.6% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_governor"><code>governor</code></a> has 37 / 1.8% missing values <span class="label label-default">Missing</

# %% [markdown]
# ### Legislative Party Composition Analysis statements based on results.
# * Analysis
#  * The Legislative Party Composition Data has quality election data grouped by each state.  An analysis of a party's control of a state's congress and legislative branch can be used from this dataset.  Missing data needs imputation to reflect an empty seat.
#
# * Keys
#  * D is for Democrat
#  * R is for Republican
#  * O is for Other
# * Numerical Values
#  * Year
# * Categorical
#  * State - there are 51 states because the District of Columbia recieves it's own electorial votes
#  * Congress House, Congress Senate, Electoral, Governor, Legislature House, Legislature Senate are all categories of Party with the number of seats per party.
#
# * Missing values appear to be when seats have been empty
# * There appears to be no variables that are redundant

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Presidential Election Results Data Preparation
# #### Make column names all lower case

# %%
df_pr.columns = map(str.lower, df_pr.columns)

# %% [markdown]
# #### Remove values that are poor quality

# %%
# Remove attributes with too much missing data
df_pr = df_pr.drop(['total_vac', 'perc_vac', 'o_placed'], axis=1)

# Remove attributes that are redundant
df_pr = df_pr.drop(['vote_r','vote_d','vote_o','vote_t','margin'], axis=1)

# %% [markdown]
# #### Impute missing values with mean values

# %%
# Each state value will have it's own mean
# Loop through each state and impute variables with missing values
states = df_pr.state.unique()
attributes = ["total_reg", "perc_reg", "total_vap", "perc_vap", "population"]
for state in states:
    for attribute in attributes:
        df_pr[attribute] = df_pr[attribute].replace("-", 0).astype(float)
        mean_value = df_pr.loc[(df_pr["state"] == state) & (df_pr[attribute] > 0), attribute].values.mean()
        df_pr.loc[((df_pr["state"] == state) & (df_pr[attribute] == 0)), [attribute]] = mean_value 
        df_pr[attribute] = df_pr[attribute].fillna(mean_value)
# Out:
# /Users/elunsford/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: Mean of empty slice.
#
# /Users/elunsford/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### Imputation of Vote Percent for Third Party
# Most elections did not have a third party candidate so the column would be missing for that election.

# %%
 df_pr['vote_perc_t'] = df_pr['vote_perc_t'].fillna(0)

# %% [markdown]
# Check for missing data

# %%
df_pr[df_pr.isnull().any(axis=1)].count()
# Out:
# year           0
# state          0
# ev_r           0
# ev_d           0
# population     0
# total_vap      0
# total_reg      0
# total_vote     0
# perc_vap       0
# perc_reg       0
# d_placed       0
# r_placed       0
# perc_margin    0
# vote_perc_d    0
# vote_perc_r    0
# vote_perc_t    0
# vote_perc_o    0
# dtype: int64

# %% [markdown]
# #### Run Profile Report on Cleaned Data

# %%
pandas_profiling.ProfileReport(df_pr)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>663 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>88.1 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>136.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>13 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_ev_d"><code>ev_d</code></a> has 419 / 63.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_ev_r"><code>ev_r</code></a> has 247 / 37.3% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_state"><code>state</code></a> has a high cardinality: 51 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_total_reg"><code>total_reg</code></a> is highly correlated with <a href="#pp_var_total_vap"><code>total_vap</code></a> (ρ = 0.92919) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_total_vap"><code>total_vap</code></a> is highly correlated with <a href="#pp_var_population"><code>population</code></a> (ρ = 0.96613) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_total_vote"><code>total_vote</code></a> is highly correlated with <a href="#pp_var_total_reg"><code>total_reg</code></a> (ρ = 0.94766) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_vote_perc_o"><code>vote_perc_o</code></a> has 33 / 5.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_vote_perc_t"><code>vote_perc_t</code></a> has 361 / 54.4% zeros <s

# %% [markdown]
# ### Legislative Party Composition Data Preparation
# #### Fill in missing data

# %%
# Fill NaN Values with E for Empty
df_lg = df_lg.fillna("E")

# %% [markdown]
# #### Make unique column for each party in congress and legislature house and senate.

# %%
# Function to break down a Series String of a list of party members into separate party column
def break_down_seats_by_party(attribute, new_attribute, party):
    df_lg[new_attribute] = df_lg[attribute].str.extract('([0-9]{1,3}%s)' % party, expand=True)
    df_lg[new_attribute] = df_lg[new_attribute].str.rstrip(party)
    df_lg[new_attribute] = df_lg[new_attribute].fillna(0)

# %%
# Run function to make unique column for each party
break_down_seats_by_party('congress house', 'con_house_d', 'D')
break_down_seats_by_party('congress house', 'con_house_r', 'R')
break_down_seats_by_party('congress sen', 'con_sen_d', 'D')
break_down_seats_by_party('congress sen', 'con_sen_r', 'R')
break_down_seats_by_party('legislature house', 'leg_house_d', 'D')
break_down_seats_by_party('legislature house', 'leg_house_r', 'R')
break_down_seats_by_party('legislature sen', 'leg_sen_d', 'D')
break_down_seats_by_party('legislature sen', 'leg_sen_r', 'R')

# %%
# remove duplicated data
df_lg = df_lg.drop(["congress house","congress sen","legislature house","legislature sen"], axis = 1)
df_lg = df_lg.drop(["congress sen class 1", "congress sen class 2", "congress sen class 3"], axis = 1)

# %% [markdown]
# #### Run Profile Report on Cleaned Data

# %%
pandas_profiling.ProfileReport(df_lg)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>2012 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>188.7 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>96.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>11 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_leg_house_d"><code>leg_house_d</code></a> has a high cardinality: 142 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_leg_house_r"><code>leg_house_r</code></a> has a high cardinality: 134 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_state"><code>state</code></a> has a high cardinality: 51 distinct values  <span class="label label-warning">Warning</span></li><li>Dataset has 88 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_con_house_d">con_house_d<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>34</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>1.7%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">

# %% [markdown]
# #### Create State Values to be the Same

# %%
df_pr['state'] = df_pr.state.str.lower()
sorted(df_pr.state.unique()) == sorted(df_lg.state.unique())
# Out:
# False

# %% [markdown]
# Datasets have different values for Washington D.C

# %%
df_pr.state = df_pr.state.replace("d. c.", "d.c.")
df_lg.state = df_lg.state.replace("washington, d.c.", "d.c.")

# %%
sorted(df_lg.state.unique()) == sorted(df_pr.state.unique())
# Out:
# True

# %% [markdown]
# ## Code Output

# %% [markdown]
# Combine states' data from both dataframes

# %%
# Merge dataset based onb state and year
merged = pd.merge(df_pr,df_lg, on=['state','year'])
# output to csv file
merged.to_csv("political_data.csv")

# %% [markdown]
# ## Machine Learning Model(s)
#  * A DecisionTreeClassifier Model can be used to predict if a state votes for a Republican or Democrat President
#  * A NaiveBayesianClassifier Model can be used to predict if a state leans Republican or Democrat
#  * A LinearRegression Model can be used to predict Voter Turnout for an election
